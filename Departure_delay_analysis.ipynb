# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("DepartureDelayAnalysis").getOrCreate()

# %%
df_dep_delays = spark\
.read\
.option("inferSchema", "true")\
.option("header", "true")\
.csv("/databricks-datasets/flights/departuredelays.csv")
df_dep_delays.show(5)
# Out:
# +-------+-----+--------+------+-----------+
# |   date|delay|distance|origin|destination|
# +-------+-----+--------+------+-----------+
# |1011245|    6|     602|   ABE|        ATL|
# |1020600|   -8|     369|   ABE|        DTW|
# |1021245|   -2|     602|   ABE|        ATL|
# |1020605|   -4|     602|   ABE|        ATL|
# |1031245|   -4|     602|   ABE|        ATL|
# +-------+-----+--------+------+-----------+
# only showing top 5 rows

# %%
# Getting the counts of total records
df_dep_delays.count()
# Out:
# 1391578

# %%
from pyspark.sql.functions import col
df_dep_delays.orderBy(col("date")).show()
# Out:
# +-------+-----+--------+------+-----------+
# |   date|delay|distance|origin|destination|
# +-------+-----+--------+------+-----------+
# |1010005|   -8|    2024|   LAX|        PBI|
# |1010010|   -6|    1980|   SEA|        CLT|
# |1010020|    0|    1273|   SFO|        DFW|
# |1010020|   -2|    1995|   SFO|        CLT|
# |1010023|   14|    1421|   SFO|        IAH|
# |1010025|   -3|    1452|   PHX|        DTW|
# |1010025|   33|    1198|   LAX|        IAH|
# |1010029|   49|    1061|   LAS|        IAH|
# |1010030|   -2|    1983|   PDX|        CLT|
# |1010030|   -7|    2191|   SFO|        PHL|
# |1010030|   -8|    1518|   LAS|        ATL|
# |1010035|   -5|    1846|   LAX|        CLT|
# |1010035|   -1|    1259|   ANC|        SEA|
# |1010040|   -6|    1382|   SLC|        ATL|
# |1010043|   18|    1413|   DEN|        JFK|
# |1010045|  -11|    1891|   LAS|        PHL|
# |1010050|   -6|    1340|   ANC|        PDX|
# |1010053|   14|    1259|   ANC|        SEA|
# |1010055|   -2|    2087|   LAX|        PHL|
# |1010059|   -9|    1042|   DEN|        ATL|
# +-------+-----+--------+------+-----------+
# only showing top 20 rows

# %%
# Getting the dates
df_dep_delays[['date']].distinct().count()
# Out:
# 95312

# %%
#Getting necessary packages--------
from pyspark.sql.functions import max,min,count,col,desc

# %%
#getting the statistics about
df_dep_delays.describe().show()
# Out:
# +-------+-----------------+------------------+-----------------+-------+-----------+
# |summary|             date|             delay|         distance| origin|destination|
# +-------+-----------------+------------------+-----------------+-------+-----------+
# |  count|          1391578|           1391578|          1391578|1391578|    1391578|
# |   mean|2180446.584000322|12.079802928761449|690.5508264718184|   NULL|       NULL|
# | stddev|838031.1536740944|38.807733749856446|513.6628153663218|   NULL|       NULL|
# |    min|          1010005|              -112|               21|    ABE|        ABE|
# |    max|          3312359|              1642|             4330|    YUM|        YUM|
# +-------+-----------------+------------------+-----------------+-------+-----------+

# %%
df_dep_delays.corr("delay","distance")
# Out:
# 0.011391992448283865

# %%
df_dep_delays.groupBy("origin","destination").\
     agg(count(col("date")).alias("Flight_count")).show()
# Out:
# +------+-----------+------------+
# |origin|destination|Flight_count|
# +------+-----------+------------+
# |   BNA|        TPA|         350|
# |   FAR|        MSP|         186|
# |   BOI|        GEG|         162|
# |   FLL|        RIC|          90|
# |   ATL|        VPS|         563|
# |   BNA|        ORF|          66|
# |   DFW|        MAF|         705|
# |   EWR|        ORF|         107|
# |   ABQ|        SLC|         254|
# |   DEN|        TUS|         649|
# |   EWR|        BZN|          21|
# |   EWR|        FLL|        1075|
# |   CAK|        RSW|         142|
# |   CRW|        ATL|         330|
# |   DAL|        BHM|         242|
# |   BNA|        JAX|         256|
# |   DEN|        LIT|         222|
# |   BUF|        BOS|         248|
# |   CID|        ATL|         231|
# |   DEN|        MFR|          95|
# +------+-----------+------------+
# only showing top 20 rows

# %%
df_dep_delays.groupBy("origin","destination").agg(count(col("date")).alias("Flight_count")).show()
# Out:
# +------+-----------+------------+
# |origin|destination|Flight_count|
# +------+-----------+------------+
# |   BNA|        TPA|         350|
# |   FAR|        MSP|         186|
# |   BOI|        GEG|         162|
# |   FLL|        RIC|          90|
# |   ATL|        VPS|         563|
# |   BNA|        ORF|          66|
# |   DFW|        MAF|         705|
# |   EWR|        ORF|         107|
# |   ABQ|        SLC|         254|
# |   DEN|        TUS|         649|
# |   EWR|        BZN|          21|
# |   EWR|        FLL|        1075|
# |   CAK|        RSW|         142|
# |   CRW|        ATL|         330|
# |   DAL|        BHM|         242|
# |   BNA|        JAX|         256|
# |   DEN|        LIT|         222|
# |   BUF|        BOS|         248|
# |   CID|        ATL|         231|
# |   DEN|        MFR|          95|
# +------+-----------+------------+
# only showing top 20 rows

# %%
# !pip install pyflightdata
# Out:
# Requirement already satisfied: pyflightdata in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f0f793d0-f53c-4b29-ba17-0faa8d2673b7/lib/python3.12/site-packages (0.8.6.2)
# Requirement already satisfied: lxml in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f0f793d0-f53c-4b29-ba17-0faa8d2673b7/lib/python3.12/site-packages (from pyflightdata) (6.0.2)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.12/site-packages (from pyflightdata) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /databricks/python3/lib/python3.12/site-packages (from pyflightdata) (4.12.3)
# Requirement already satisfied: jsonpath-rw in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f0f793d0-f53c-4b29-ba17-0faa8d2673b7/lib/python3.12/site-packages (from pyflightdata) (1.4.0)
# Requirement already satisfied: metar in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f0f793d0-f53c-4b29-ba17-0faa8d2673b7/lib/python3.12/site-packages (from pyflightdata) (1.11.0)
# Requirement already satisfied: html5lib in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f0f793d0-f53c-4b29-ba17-0faa8d2673b7/lib/python3.12/site-packages (from pyflightdata) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /databricks/python3/lib/python3.12/site-packages (from beautifulsoup4->pyflightdata) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/lib/python3/dist-packages (from html5lib->pyflightdata) (1.16.0)
# Requirement already satisfied: webencodings in /databricks/python3/lib/python3.12/site-packages (from html5lib->pyflightdata) (0.5.1)
# Requirement already satisfied: ply in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f0f793d0-f53c-4b29-ba17-0faa8d2673b7/lib/python3.12/site-packages (from jsonpath-rw->pyflightdata) (3.11)
# Requirement already satisfied: decorator in /databricks/python3/lib/python3.12/site-packages (from jsonpath-rw->pyflightdata) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests->pyflightdata) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests->pyflightdata) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests->pyflightdata) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests->pyflightdata) (2025.1.31)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %restart_python

# %%
from pyflightdata import FlightData
fd =FlightData()
print(fd.get_airport_details("CCU"))
# Out:
# {'name': 'Kolkata Subhas Chandra Bose International Airport', 'code': {'iata': 'CCU', 'icao': 'VECC'}, 'delayIndex': {'arrivals': 0.42, 'departures': 1.08}, 'stats': {'arrivals': {'delayIndex': 0.42, 'delayAvg': 5, 'percentage': {'delayed': 0.08, 'canceled': 0, 'trend': 'down'}, 'recent': {'delayIndex': 0.42, 'delayAvg': 5, 'percentage': {'delayed': 0.08, 'canceled': 0, 'trend': 'down'}, 'quantity': {'onTime': 12, 'delayed': 1, 'canceled': 0}}, 'today': {'percentage': {'delayed': 0.13, 'canceled': 0.01}, 'quantity': {'onTime': 94, 'delayed': 25, 'canceled': 1}}, 'yesterday': {'percentage': {'delayed': 0.13, 'canceled': 0}, 'quantity': {'onTime': 161, 'delayed': 24, 'canceled': 0}}, 'tomorrow': {'percentage': {'canceled': 0}, 'quantity': {'canceled': 0}}}, 'departures': {'delayIndex': 1.08, 'delayAvg': 13, 'percentage': {'delayed': 0.43, 'canceled': 0, 'trend': 'down'}, 'recent': {'delayIndex': 1.08, 'delayAvg': 13, 'percentage': {'delayed': 0.43, 'canceled': 0, 'trend': 'down'}, 'quantity': {'onTime': 8, 'delayed': 6, 'canceled': 0}}, 'today': {'percentage': {'delayed': 0.31, 'canceled': 0.01}, 'quantity': {'onTime': 76, 'delayed': 59, 'canceled': 1}}, 'yesterday': {'percentage': {'delayed': 0.3, 'canceled': 0}, 'quantity': {'onTime': 127, 'delayed': 55, 'canceled': 0}}, 'tomorrow': {'percentage': {'canceled': 0}, 'quantity': {'canceled': 0}}}}, 'position': {'latitude': 22.65473, 'longitude': 88.446716, 'elevation': {'m': 4, 'ft': 13}, 'country': {'name': 'India', 'code': 'IN'}, 'region': {'city': 'Kolkata'}}, 'timezone': {'name': 'Asia/Kolkata', 'offset': 19800, 'abbr': 'IST', 'abbrName': 'India Standard Time', 'isDst': False}, 'url': {'homepage': 'http://www.aai.aero/kolkata/index.jsp', 'webcam': 'None', 'wikipedia': 'https://en.wikipedia.org/wiki/Kolkata_International_Airport'}, 'airportImages': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/83621_1423530936_tb.jpg', 'link': 'https://www.jetphotos.com/photo/7980796', 'copyright': 'M. Azizul Islam', 'source': 'Jetphotos.com'}], 'medium': [{'src': 'https://cdn.jetphotos.com/400/6/83621_1423530936.jpg', 'link': 'https://www.jetphotos.com/photo/7980796', 'copyright': 'M. Azizul Islam', 'source': 'Jetphotos.com'}], 'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/83621_1423530936.jpg', 'link': 'https://www.jetphotos.com/photo/7980796', 'copyright': 'M. Azizul Islam', 'source': 'Jetphotos.com'}]}, 'visible': True}

# %%
pwd
# Out:
# '/Workspace/Users/sandutta2020@gmail.com/Pyspark'

# %%
df_dep_delays.orderBy(desc(col("delay"))).show()
# Out:
# +-------+-----+--------+------+-----------+
# |   date|delay|distance|origin|destination|
# +-------+-----+--------+------+-----------+
# |3090615| 1642|     807|   TPA|        DFW|
# |2190925| 1638|    1604|   SFO|        ORD|
# |2021245| 1636|     972|   FLL|        DFW|
# |3020700| 1592|     974|   RSW|        ORD|
# |1180805| 1560|     548|   BNA|        DFW|
# |3031210| 1553|    1404|   PDX|        DFW|
# |3070645| 1543|     887|   CLE|        DFW|
# |2210630| 1511|     873|   MCO|        ORD|
# |1300915| 1500|    1517|   EGE|        JFK|
# |1150715| 1496|    1033|   ONT|        DFW|
# |1300725| 1482|     626|   EGE|        DFW|
# |3130705| 1470|     479|   ELP|        DFW|
# |2120745| 1461|    1079|   AUS|        LAX|
# |1051805| 1461|    1734|   CMH|        LAX|
# |1210725| 1444|    1018|   IAD|        DFW|
# |2050720| 1418|    1889|   LAS|        MIA|
# |2030630| 1417|    1141|   FAT|        DFW|
# |1110705| 1404|     978|   PSP|        DFW|
# |2220705| 1400|     400|   MCI|        DFW|
# |1210835| 1350|     859|   SLC|        DFW|
# +-------+-----+--------+------+-----------+
# only showing top 20 rows

# %%
df_dep_delays.where((col("origin")=='TPA') & (col("destination")=='DFW')).show()
# Out:
# +-------+-----+--------+------+-----------+
# |   date|delay|distance|origin|destination|
# +-------+-----+--------+------+-----------+
# |1011700|   21|     807|   TPA|        DFW|
# |1010735|    1|     807|   TPA|        DFW|
# |1011230|    1|     807|   TPA|        DFW|
# |1010920|   -6|     807|   TPA|        DFW|
# |1011500|   -6|     807|   TPA|        DFW|
# |1010625|    0|     807|   TPA|        DFW|
# |1011905|   -5|     807|   TPA|        DFW|
# |1021700|    0|     807|   TPA|        DFW|
# |1020735|   -6|     807|   TPA|        DFW|
# |1021230|   97|     807|   TPA|        DFW|
# |1020920|    3|     807|   TPA|        DFW|
# |1021500|   11|     807|   TPA|        DFW|
# |1020625|   -2|     807|   TPA|        DFW|
# |1021905|   86|     807|   TPA|        DFW|
# |1031700|    9|     807|   TPA|        DFW|
# |1030735|    0|     807|   TPA|        DFW|
# |1031230|   -7|     807|   TPA|        DFW|
# |1030920|    0|     807|   TPA|        DFW|
# |1031500|   14|     807|   TPA|        DFW|
# |1030625|   -3|     807|   TPA|        DFW|
# +-------+-----+--------+------+-----------+
# only showing top 20 rows

# %%
df_dep_delays.where((col("destination")=='TPA') & (col("origin")=='DFW')).orderBy("date").show()
# Out:
# +-------+-----+--------+------+-----------+
# |   date|delay|distance|origin|destination|
# +-------+-----+--------+------+-----------+
# |1010825|   -4|     807|   DFW|        TPA|
# |1011100|    1|     807|   DFW|        TPA|
# |1011305|   23|     807|   DFW|        TPA|
# |1011510|   -1|     807|   DFW|        TPA|
# |1011700|   31|     807|   DFW|        TPA|
# |1011815|   -1|     807|   DFW|        TPA|
# |1012040|   -1|     807|   DFW|        TPA|
# |1020825|   95|     807|   DFW|        TPA|
# |1021100|    7|     807|   DFW|        TPA|
# |1021305|    0|     807|   DFW|        TPA|
# |1021510|   89|     807|   DFW|        TPA|
# |1021700|   20|     807|   DFW|        TPA|
# |1021815|   -2|     807|   DFW|        TPA|
# |1022040|    5|     807|   DFW|        TPA|
# |1030825|   -2|     807|   DFW|        TPA|
# |1031100|   22|     807|   DFW|        TPA|
# |1031305|   -2|     807|   DFW|        TPA|
# |1031510|   -1|     807|   DFW|        TPA|
# |1031700|   -2|     807|   DFW|        TPA|
# |1031815|   30|     807|   DFW|        TPA|
# +-------+-----+--------+------+-----------+
# only showing top 20 rows

# %%
df_dep_delays.where((col("destination")=='TPA') & (col("origin")=='DFW')).orderBy("date").select("distance").distinct().show()
# Out:
# +--------+
# |distance|
# +--------+
# |     807|
# +--------+

# %%
import pandas as pd

df =df_dep_delays[[col("date")]].distinct().toPandas()
df["converted_date"]=pd.to_datetime(df['date'],unit='m',origin='unix')
df.head()
# Out:
#       date      converted_date
# 0  1060755 1972-01-07 15:15:00
# 1  1121305 1972-02-18 16:25:00
# 2  1271045 1972-06-01 16:05:00
# 3  1291355 1972-06-15 18:35:00
# 4  1071430 1972-01-15 01:10:00

# %%
df_changed_date=spark.createDataFrame(df)

# %%
df_changed_date.where(col("date") ==1010005).show()
# Out:
# +-------+-------------------+
# |   date|     converted_date|
# +-------+-------------------+
# |1010005|1971-12-03 09:25:00|
# +-------+-------------------+

# %%
from pyspark.sql.functions import to_date
df_dep_delays.withColumn("parsed_date",col("date").cast("string")).withColumn("date_converted",to_date(col("parsed_date"),'yyyyMMdd')).show()
# Out:
# ---------------------------------------------------------------------------
# DateTimeException                         Traceback (most recent call last)
# File <command-8328182518415259>, line 2
#       1 from pyspark.sql.functions import to_date
# ----> 2 df_dep_delays.withColumn("parsed_date",col("date").cast("string")).withColumn("date_converted",to_date(col("parsed_date"),'yyyyMMdd')).show()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:1123, in DataFrame.show(self, n, truncate, vertical)
#    1122 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
# -> 1123     print(self._show_string(n, truncate, vertical))
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:876, in DataFrame._show_string(self, n, truncate, vertical)
#     859     except ValueError:
#     860         raise PySparkTypeError(
#     861             errorClass="NOT_BOOL",
#     862             messageParameters={
#    (...)
#     865             },
#     866         )
#     868 table, _ = DataFrame(
#     869     plan.ShowString(
#     870         child=self._plan,
#     871         num_rows=n,
#     872         truncate=_truncate,
#     873         vertical=vertical,
#     874     ),
#     875     session=self._session,
# --> 876 )._to_table()
#     877 return table[0][0].as_py()
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:1890, in DataFrame._to_table(self)
#    1888 def _to_table(self) -> Tuple["pa.Table", Optional[StructType]]:
#    1889     query = self._plan.to_proto(self._session.client)
# -> 1890     table, schema, self._execution_info = self._session.client.to_table(
#    1891         query, self._plan.observations
#    1892     )
#    1893     assert table is not None
#    1894     return (table, schema)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1239, in SparkConnectClient.to_table(self, plan, observations)
#    1237 req = self._execute_plan_request_with_metadata()
#    1238 req.plan.CopyFrom(plan)
# -> 1239 table, schema, metrics, observed_metrics, _ = self._execute_and_fetch(req, observations)
#    1241 # Create a query execution object.
#    1242 ei = ExecutionInfo(metrics, observed_metrics)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2059, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
#    2056 properties: Dict[str, Any] = {}
#    2058 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
# -> 2059     for response in self._execute_and_fetch_as_iterator(
#    2060         req, observations, extra_request_metadata or [], progress=progress
#    2061     ):
#    2062         if isinstance(response, StructType):
#    2063             schema = response
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2035, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
#    2033     raise kb
#    2034 except Exception as error:
# -> 2035     self._handle_error(error)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2355, in SparkConnectClient._handle_error(self, error)
#    2353     self.thread_local.inside_error_handling = True
#    2354     if isinstance(error, grpc.RpcError):
# -> 2355         self._handle_rpc_error(error)
#    2356     raise error
#    2357 finally:
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:2433, in SparkConnectClient._handle_rpc_error(self, rpc_error)
#    2429             logger.debug(f"Received ErrorInfo: {info}")
#    2431             self._handle_rpc_error_with_error_info(info, status.message, status_code)  # EDGE
# -> 2433             raise convert_exception(
#    2434                 info,
#    2435                 status.message,
#    2436                 self._fetch_enriched_error(info),
#    2437                 self._display_server_stack_trace(),
#    2438                 status_code,
#    2439             ) from None
#    2441     raise SparkConnectGrpcException(
#    2442         message=status.message,
#    2443         sql_state=ErrorCode.CLIENT_UNEXPECTED_MISSING_SQL_STATE,  # EDGE
#    2444         grpc_status_code=status_code,
#    2445     ) from None
#    2446 else:
#
# DateTimeException: [CANNOT_PARSE_TIMESTAMP] Text '1011245' could not be parsed at index 6. Use `try_to_date` to tolerate invalid input string and return NULL instead. SQLSTATE: 22007
#
# JVM stacktrace:
# org.apache.spark.SparkDateTimeException
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.ansiDateTimeParseError(QueryExecutionErrors.scala:321)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.ansiDateTimeParseError(QueryExecutionErrors.scala:-1)
# 	at com.databricks.photon.NativeToTimestampWrapper.evalOutput(NativeToTimestampWrapper.java:76)
# 	at com.databricks.photon.NativeToTimestampWrapper.eval(NativeToTimestampWrapper.java:106)
# 	at 0xc331ca7 <photon>.operator()(external/workspace_spark_4_0/photon/exprs/to-timestamp-expr.cc:138)
# 	at 0xbc66c2b <photon>.Eval(external/workspace_spark_4_0/photon/exprs/to-timestamp-expr.cc:138)
# 	at 0x9351dff <photon>.Eval(external/workspace_spark_4_0/photon/exprs/unary-expr.h:105)
# 	at 0x930d37f <photon>.Eval(external/workspace_spark_4_0/photon/exprs/unary-expr.h:105)
# 	at 0xc0fb63f <photon>.Eval(external/workspace_spark_4_0/photon/exprs/coalesce-expr.cc:55)
# 	at 0x75a6d6f <photon>.NextImpl(external/workspace_spark_4_0/photon/exec-nodes/project-node.cc:97)
# 	at 0x7494007 <photon>.Next(external/workspace_spark_4_0/photon/exec-nodes/exec-node.cc:222)
# 	at com.databricks.photon.JniApiImpl.getNext(JniApi.scala:-2)
# 	at com.databricks.photon.JniApi.getNext(JniApi.scala:-1)
# 	at com.databricks.photon.JniExecNode.next(JniExecNode.java:84)
# 	at com.databricks.photon.PhotonColumnarBatchResultHandler$$anon$2.next(PhotonExec.scala:1508)
# 	at com.databricks.photon.PhotonColumnarBatchResultHandler$$anon$2.next(PhotonExec.scala:1504)
# 	at com.databricks.photon.PhotonBasicEvaluatorFactory$PhotonBasicEvaluator$$anon$1.$anonfun$next$2(PhotonBasicEvaluatorFactory.scala:293)
# 	at com.databricks.photon.PhotonResultHandler.timeit(PhotonResultHandler.scala:30)
# 	at com.databricks.photon.PhotonResultHandler.timeit$(PhotonResultHandler.scala:28)
# 	at com.databricks.photon.PhotonColumnarBatchResultHandler.timeit(PhotonExec.scala:1492)
# 	at com.databricks.photon.PhotonBasicEvaluatorFactory$PhotonBasicEvaluator$$anon$1.$anonfun$next$1(PhotonBasicEvaluatorFactory.scala:293)
# 	at com.databricks.photon.metrics.BillableTimeTaskMetrics.withPhotonBilling(BillableTimeTaskMetrics.scala:71)
# 	at org.apache.spark.TaskContext.runFuncAsBillable(TaskContext.scala:273)
# 	at com.databricks.photon.PhotonBasicEvaluatorFactory$PhotonBasicEvaluator$$anon$1.next(PhotonBasicEvaluatorFactory.scala:291)
# 	at com.databricks.photon.CloseableIterator$$anon$10.next(CloseableIterator.scala:212)
# 	at scala.collection.Iterator$$anon$10.nextCur(Iterator.scala:594)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:608)
# 	at org.apache.spark.sql.execution.collect.UnsafeRowBatchUtils$.$anonfun$encodeUnsafeRows$5(UnsafeRowBatchUtils.scala:88)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
# 	at org.apache.spark.sql.execution.collect.UnsafeRowBatchUtils$.$anonfun$encodeUnsafeRows$3(UnsafeRowBatchUtils.scala:88)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
# 	at org.apache.spark.sql.execution.collect.UnsafeRowBatchUtils$.$anonfun$encodeUnsafeRows$1(UnsafeRowBatchUtils.scala:68)
# 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
# 	at org.apache.spark.sql.execution.collect.UnsafeRowBatchUtils$.encodeUnsafeRows(UnsafeRowBatchUtils.scala:62)
# 	at org.apache.spark.sql.execution.collect.Collector.$anonfun$processFunc$2(Collector.scala:207)
# 	at org.apache.spark.scheduler.ResultTask.$anonfun$runTask$2(ResultTask.scala:76)
# 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
# 	at org.apache.spark.scheduler.ResultTask.$anonfun$runTask$1(ResultTask.scala:76)
# 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:62)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:233)
# 	at org.apache.spark.scheduler.Task.doRunTask(Task.scala:197)
# 	at org.apache.spark.scheduler.Task.$anonfun$run$4(Task.scala:160)
# 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
# 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:104)
# 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:109)
# 	at scala.util.Using$.resource(Using.scala:296)
# 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:108)
# 	at org.apache.spark.scheduler.TaskExecutionUtils$.withUCHandleForTaskExecution(Task.scala:355)
# 	at org.apache.spark.scheduler.Task.$anonfun$run$3(Task.scala:154)
# 	at org.apache.spark.scheduler.TaskExecutionUtils$.withCredentialsForTaskExecution(Task.scala:333)
# 	at org.apache.spark.scheduler.Task.$anonfun$run$1(Task.scala:113)
# 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:108)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$11(Executor.scala:1255)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:86)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:83)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:110)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:1259)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.ExecutorFrameProfiler$.record(ExecutorFrameProfiler.scala:110)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:1108)
# 	at com.databricks.aether.RDDTask.run(RDDTask.scala:252)
# 	at com.databricks.aether.worker.WorkerTaskAttemptThread.$anonfun$runInternal$1(AetherWorkerImpl.scala:362)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.aether.AetherInt64Gauge.scopedAdd(AetherServiceMetricImpls.scala:129)
# 	at com.databricks.aether.worker.WorkerTaskAttemptThread.runInternal(AetherWorkerImpl.scala:351)
# 	at com.databricks.aether.worker.WorkerTaskAttemptThread.run(AetherWorkerImpl.scala:328)
# 	at com.databricks.aether.FairBlockingQueue$SlotCountingRunnable.run(FairBlockingQueue.java:638)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1136)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:635)
# 	at java.lang.Thread.run(Thread.java:840)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$runJob$1(DAGScheduler.scala:1709)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:1693)
# 	at org.apache.spark.SparkContext.runJobInternal(SparkContext.scala:3288)
# 	at org.apache.spark.sql.execution.collect.Collector.$anonfun$runSparkJobs$1(Collector.scala:352)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.execution.collect.Collector.runSparkJobs(Collector.scala:296)
# 	at org.apache.spark.sql.execution.collect.Collector.$anonfun$collect$1(Collector.scala:385)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.execution.collect.Collector.collect(Collector.scala:382)
# 	at org.apache.spark.sql.execution.collect.Collector$.collect(Collector.scala:116)
# 	at org.apache.spark.sql.execution.collect.Collector$.collect(Collector.scala:124)
# 	at org.apache.spark.sql.execution.qrc.InternalRowFormat$.collect(cachedSparkResults.scala:94)
# 	at org.apache.spark.sql.execution.qrc.InternalRowFormat$.collect(cachedSparkResults.scala:90)
# 	at org.apache.spark.sql.execution.qrc.InternalRowFormat$.collect(cachedSparkResults.scala:78)
# 	at org.apache.spark.sql.execution.qrc.ResultCacheManager.$anonfun$computeResult$1(ResultCacheManager.scala:613)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.execution.qrc.ResultCacheManager.collectResult$1(ResultCacheManager.scala:607)
# 	at org.apache.spark.sql.execution.qrc.ResultCacheManager.computeResult(ResultCacheManager.scala:624)
# 	at org.apache.spark.sql.execution.qrc.ResultCacheManager.getOrComputeResultInternal(ResultCacheManager.scala:448)
# 	at org.apache.spark.sql.execution.qrc.ResultCacheManager.getOrComputeResult(ResultCacheManager.scala:362)
# 	at org.apache.spark.sql.execution.SparkPlan.$anonfun$executeCollectResult$1(SparkPlan.scala:605)
# 	at com.databricks.spark.util.FrameProfiler$.$anonfun$record$1(FrameProfiler.scala:114)
# 	at com.databricks.spark.util.FrameProfilerExporter$.maybeExportFrameProfiler(FrameProfilerExporter.scala:200)
# 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:105)
# 	at org.apache.spark.sql.execution.SparkPlan.executeCollectResult(SparkPlan.scala:602)
# 	at org.apache.spark.sql.classic.Dataset.collectResult(Dataset.scala:1790)
# 	at org.apache.spark.sql.classic.Dataset.collectFromPlan(Dataset.scala:2776)
# 	at org.apache.spark.sql.classic.Dataset.$anonfun$head$1(Dataset.scala:1660)
# 	at org.apache.spark.sql.classic.Dataset.$anonfun$withAction$4(Dataset.scala:2766)
# 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
# 	at org.apache.spark.sql.execution.QueryExecution.withQueryExecutionId(QueryExecution.scala:932)
# 	at org.apache.spark.sql.classic.Dataset.$anonfun$withAction$3(Dataset.scala:2764)
# 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:1607)
# 	at org.apache.spark.sql.classic.Dataset.$anonfun$withAction$2(Dataset.scala:2764)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$18(SQLExecution.scala:600)
# 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:111)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$16(SQLExecution.scala:513)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSessionTagsApplied(SQLExecution.scala:932)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$15(SQLExecution.scala:434)
# 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
# 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$14(SQLExecution.scala:434)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:967)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$1(SQLExecution.scala:433)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId0(SQLExecution.scala:255)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:885)
# 	at org.apache.spark.sql.classic.Dataset.withAction(Dataset.scala:2763)
# 	at org.apache.spark.sql.classic.Dataset.head(Dataset.scala:1660)
# 	at org.apache.spark.sql.Dataset.take(Dataset.scala:2822)
# 	at org.apache.spark.sql.classic.Dataset.getRows(Dataset.scala:495)
# 	at org.apache.spark.sql.classic.Dataset.showString(Dataset.scala:531)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformShowString(SparkConnectPlanner.scala:417)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.$anonfun$transformRelation$1(SparkConnectPlanner.scala:215)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$8(SessionHolder.scala:739)
# 	at org.apache.spark.sql.connect.service.SessionHolder.measureSubtreeRelationNodes(SessionHolder.scala:755)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$usePlanCache$6(SessionHolder.scala:738)
# 	at scala.Option.getOrElse(Option.scala:201)
# 	at org.apache.spark.sql.connect.service.SessionHolder.usePlanCache(SessionHolder.scala:736)
# 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.transformRelation(SparkConnectPlanner.scala:212)
# 	at org.apache.spark.sql.connect.execution.SparkConnectPlanExecution.handlePlan(SparkConnectPlanExecution.scala:94)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handlePlan(ExecuteThreadRunner.scala:376)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:282)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:238)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:532)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:860)
# 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:532)
# 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
# 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:124)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withClassLoaderIfNeeded(ArtifactManager.scala:118)
# 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:123)
# 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:531)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:238)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$execute$1(ExecuteThreadRunner.scala:141)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries(UtilizationMetrics.scala:43)
# 	at com.databricks.spark.connect.service.UtilizationMetrics.recordActiveQueries$(UtilizationMetrics.scala:40)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.recordActiveQueries(ExecuteThreadRunner.scala:53)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:139)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$2(ExecuteThreadRunner.scala:586)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.scala:18)
# 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
# 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:104)
# 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:109)
# 	at scala.util.Using$.resource(Using.scala:296)
# 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:108)
# 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:586)
