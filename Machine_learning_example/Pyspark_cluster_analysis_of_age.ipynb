# %%
from pyspark.sql import SparkSession
spark =SparkSession.builder.appName("People_data_analysis").getOrCreate()
df_people=spark.read.parquet('/Volumes/movie_catalog/movie_schema/temp_storage/people_data')

# %%
from pyspark.ml.feature import VectorAssembler,MinMaxScaler
from pyspark.ml.clustering import KMeans

# %%
features =df_people.select("age","salary")

# %%
assembler =VectorAssembler(inputCols=["age","salary"],outputCol="features")

# %%
Feature_vector=assembler.transform(features)

# %%
scaler =MinMaxScaler(inputCol="features",outputCol="scaled_features")
scaler_model=scaler.fit(Feature_vector)
scaled_data=scaler_model.transform(Feature_vector)

# %%
kmeans =KMeans(featuresCol="scaled_features",k=3,seed=42)

# %%
model=kmeans.fit(scaled_data)
clusted_data=model.transform(scaled_data)
clusted_data.show()
# Out:
# +----+--------+---------------+--------------------+----------+
# | age|  salary|       features|     scaled_features|prediction|
# +----+--------+---------------+--------------------+----------+
# |47.0| 32718.0| [47.0,32718.0]|[0.4375,0.1339196...|         1|
# |38.0|111156.0|[38.0,111156.0]|[0.25,0.855895658...|         0|
# |51.0| 84680.0| [51.0,84680.0]|[0.52083333333333...|         2|
# |61.0| 54054.0| [61.0,54054.0]|[0.72916666666666...|         1|
# |52.0| 79032.0| [52.0,79032.0]|[0.54166666666666...|         2|
# |32.0| 55079.0| [32.0,55079.0]|[0.125,0.33973960...|         0|
# |54.0| 74814.0| [54.0,74814.0]|[0.58333333333333...|         2|
# |27.0| 74987.0| [27.0,74987.0]|[0.02083333333333...|         0|
# |42.0| 78322.0| [42.0,78322.0]|[0.33333333333333...|         0|
# |30.0| 65783.0| [30.0,65783.0]|[0.08333333333333...|         0|
# |46.0| 94190.0| [46.0,94190.0]|[0.41666666666666...|         2|
# |28.0| 87395.0| [28.0,87395.0]|[0.04166666666666...|         0|
# |47.0| 63085.0| [47.0,63085.0]|[0.4375,0.4134301...|         0|
# |57.0| 54775.0| [57.0,54775.0]|[0.64583333333333...|         1|
# |51.0|105416.0|[51.0,105416.0]|[0.52083333333333...|         2|
# |66.0| 80581.0| [66.0,80581.0]|[0.83333333333333...|         2|
# |68.0| 89429.0| [68.0,89429.0]|[0.875,0.65591130...|         2|
# |49.0| 75419.0| [49.0,75419.0]|[0.47916666666666...|         2|
# |53.0|103004.0|[53.0,103004.0]|[0.5625,0.7808612...|         2|
# |31.0| 52595.0| [31.0,52595.0]|[0.10416666666666...|         0|
# +----+--------+---------------+--------------------+----------+
# only showing top 20 rows

# %%
clusted_data.show(truncate=False)
# Out:
# +----+--------+---------------+-----------------------------------------+----------+
# |age |salary  |features       |scaled_features                          |prediction|
# +----+--------+---------------+-----------------------------------------+----------+
# |47.0|32718.0 |[47.0,32718.0] |[0.4375,0.13391965465030123]             |1         |
# |38.0|111156.0|[38.0,111156.0]|[0.25,0.8558956587370621]                |0         |
# |51.0|84680.0 |[51.0,84680.0] |[0.5208333333333333,0.6121995333360947]  |2         |
# |61.0|54054.0 |[61.0,54054.0] |[0.7291666666666666,0.3303050803775652]  |1         |
# |52.0|79032.0 |[52.0,79032.0] |[0.5416666666666666,0.5602129901926944]  |2         |
# |32.0|55079.0 |[32.0,55079.0] |[0.125,0.33973960706346906]              |0         |
# |54.0|74814.0 |[54.0,74814.0] |[0.5833333333333333,0.5213887623281651]  |2         |
# |27.0|74987.0 |[27.0,74987.0] |[0.020833333333333332,0.5229811263444201]|0         |
# |42.0|78322.0 |[42.0,78322.0] |[0.3333333333333333,0.5536778546346537]  |0         |
# |30.0|65783.0 |[30.0,65783.0] |[0.08333333333333333,0.43826367891314255]|0         |
# |46.0|94190.0 |[46.0,94190.0] |[0.41666666666666663,0.699733532148725]  |2         |
# |28.0|87395.0 |[28.0,87395.0] |[0.041666666666666664,0.6371895235333913]|0         |
# |47.0|63085.0 |[47.0,63085.0] |[0.4375,0.4134301637925877]              |0         |
# |57.0|54775.0 |[57.0,54775.0] |[0.6458333333333333,0.33694146451467416] |1         |
# |51.0|105416.0|[51.0,105416.0]|[0.5208333333333333,0.8030623092960002]  |2         |
# |66.0|80581.0 |[66.0,80581.0] |[0.8333333333333333,0.5744706310087581]  |2         |
# |68.0|89429.0 |[68.0,89429.0] |[0.875,0.6559113062447363]               |2         |
# |49.0|75419.0 |[49.0,75419.0] |[0.47916666666666663,0.5269574341769181] |2         |
# |53.0|103004.0|[53.0,103004.0]|[0.5625,0.7808612572312196]              |2         |
# |31.0|52595.0 |[31.0,52595.0] |[0.10416666666666666,0.3168758370266054] |0         |
# +----+--------+---------------+-----------------------------------------+----------+
# only showing top 20 rows
