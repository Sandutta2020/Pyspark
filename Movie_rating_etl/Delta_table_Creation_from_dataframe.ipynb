# %%
df = spark.read.format("csv").load('/Volumes/movie_catalog/movie_schema/movie_user_ratings/*.csv')
display(df)

# %%
df.write.format("delta").save("/Volumes/movie_catalog/movie_schema/delta_storage_vol")

# %%
spark.read.format("delta").load("/Volumes/movie_catalog/movie_schema/delta_storage_vol").show()
