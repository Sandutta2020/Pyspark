# %%
import os
import shutil
volume_folder ='/Volumes/movie_catalog/movie_schema/monthwise_rating_data'
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File <command-6372462211579078>, line 4
#       2 import shutil
#       3 volume_folder ='/Volumes/movie_catalog/movie_schema/monthwise_rating_data'
# ----> 4 shutil.rmtree(volume_folder)
#
# File /usr/lib/python3.11/shutil.py:763, in rmtree(path, ignore_errors, onerror, dir_fd)
#     761         os.rmdir(path, dir_fd=dir_fd)
#     762     except OSError:
# --> 763         onerror(os.rmdir, path, sys.exc_info())
#     764 else:
#     765     try:
#     766         # symlinks to directories are forbidden, see bug #1669
#
# File /usr/lib/python3.11/shutil.py:761, in rmtree(path, ignore_errors, onerror, dir_fd)
#     759 fd_closed = True
#     760 try:
# --> 761     os.rmdir(path, dir_fd=dir_fd)
#     762 except OSError:
#     763     onerror(os.rmdir, path, sys.exc_info())
#
# ...

# %% [markdown]
# To Drop one volumne we need to use below location if volume is not empty

# %%
dbutils.fs.rm("/Volumes/movie_catalog/movie_schema/monthwise_rating_data/",True)
# Out:
# True

# %%
dbutils.fs.rm("/Volumes/movie_catalog/movie_schema/movie_user_ratings/",True)
# Out:
# True

# %%
import os
import shutil
source_folder ='/Volumes/movie_catalog/movie_schema/movie_user_ratings'
target_folder ='/Volumes/movie_catalog/movie_schema/temp_storage'
for filename in os.listdir(source_folder):
        if filename.endswith(".csv"):
            shutil.move(os.path.join(source_folder,filename),os.path.join(target_folder,filename))

# %%
import os
import shutil
source_folder ='/Volumes/movie_catalog/movie_schema/temp_storage'
target_folder ='/Volumes/movie_catalog/movie_schema/movie_user_ratings'
filename='part-00001-tid-1067718856497460044-263fe2a3-9b1e-4978-8850-739340ce3ede-209-1-c000.csv'
shutil.move(os.path.join(source_folder,filename),os.path.join(target_folder,filename))
# Out:
# '/Volumes/movie_catalog/movie_schema/movie_user_ratings/part-00001-tid-1067718856497460044-263fe2a3-9b1e-4978-8850-739340ce3ede-209-1-c000.csv'

# %%
import os
import shutil
source_folder ='/Volumes/movie_catalog/movie_schema/temp_storage'
target_folder ='/Volumes/movie_catalog/movie_schema/movie_user_ratings'
filename='part-00002-tid-5978359971357203344-9b17f40a-e448-431c-9364-45b68f8abfe8-219-1-c000.csv'
shutil.move(os.path.join(source_folder,filename),os.path.join(target_folder,filename))
# Out:
# '/Volumes/movie_catalog/movie_schema/movie_user_ratings/part-00002-tid-5978359971357203344-9b17f40a-e448-431c-9364-45b68f8abfe8-219-1-c000.csv'

# %%
import os
import shutil
source_folder ='/Volumes/movie_catalog/movie_schema/temp_storage'
target_folder ='/Volumes/movie_catalog/movie_schema/movie_user_ratings'
filename='part-00003-tid-8314286054259934035-386bfe76-a7ec-4b1e-8156-f5ba28b48ea5-229-1-c000.csv'
shutil.move(os.path.join(source_folder,filename),os.path.join(target_folder,filename))
# Out:
# '/Volumes/movie_catalog/movie_schema/movie_user_ratings/part-00003-tid-8314286054259934035-386bfe76-a7ec-4b1e-8156-f5ba28b48ea5-229-1-c000.csv'

# %%
# %sql
DROP TABLE IF EXISTS movie_catalog.movie_schema.movie_ratings_bronze_st;
DROP TABLE IF EXISTS movie_catalog.movie_schema.movie_ratings_silver_st;
DROP TABLE IF EXISTS movie_catalog.movie_schema.Top_movies_per_months_mview;
DROP TABLE IF EXISTS movie_catalog.movie_schema.Movie_ratings_gold_st;
DROP TABLE IF EXISTS movie_catalog.movie_schema.movie_rating_history;
DROP TABLE IF EXISTS movie_catalog.movie_schema.movie_rating_history_dlt;

# %%
# %sql
DROP TABLE IF EXISTS movie_catalog.movie_schema.Movie_ratings_gold_st;
DROP TABLE IF EXISTS movie_catalog.movie_schema.Movie_ratings_gold;
