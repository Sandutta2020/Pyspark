-- %%
select count(*) from movie_catalog.movie_schema.movie_table_bronze;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>133847</td></tr></tbody></table></div>

-- %%
select * from movie_catalog.movie_schema.movie_table_bronze limit 10
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MovieID</th><th>Rating</th><th>Review_ym</th></tr></thead><tbody><tr><td>MovieID</td><td>Rating</td><td>Review_ym</td></tr><tr><td>593</td><td>3</td><td>200011</td></tr><tr><td>2073</td><td>5</td><td>200011</td></tr><tr><td>2094</td><td>3</td><td>200011</td></tr><tr><td>3044</td><td>5</td><td>200011</td></tr><tr><td>780</td><td>5</td><td>200011</td></tr><tr><td>1610</td><td>4</td><td>200011</td></tr><tr><td>2278</td><td>4</td><td>200011</td></tr><tr><td>2424</td><td>3</td><td>200011</td></tr><tr><td>1480</td><td>3</td><td>200011</td></tr></tbody></table></div>

-- %%
select distinct Review_ym from movie_catalog.movie_schema.movie_table_bronze;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Review_ym</th></tr></thead><tbody><tr><td>Review_ym</td></tr><tr><td>200004</td></tr><tr><td>200005</td></tr><tr><td>200006</td></tr></tbody></table></div>

-- %%
select count(*) from movie_catalog.movie_schema.movie_ratings_bronze_st
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>904791</td></tr></tbody></table></div>

-- %%
delete from movie_catalog.movie_schema.movie_ratings_bronze_st;
delete from movie_catalog.movie_schema.movie_ratings_silver_st;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>644842</td></tr></tbody></table></div>

-- %%
select * from movie_catalog.movie_schema.movie_ratings_bronze_st limit 100;
select * from movie_catalog.movie_schema.movie_ratings_silver_st limit 100;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MovieID</th><th>Rating</th><th>Review_ym</th><th>_rescued_data</th></tr></thead><tbody></tbody></table></div>

-- %%
select * from movie_catalog.movie_schema.top_movies_per_months_mview limit 100
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MovieID</th><th>Title</th><th>Rating_avg</th><th>Review_ym</th></tr></thead><tbody><tr><td>260</td><td>Star Wars: Episode IV - A New Hope (1977)</td><td>3.76</td><td>200004</td></tr><tr><td>3359</td><td>Breaking Away (1979)</td><td>3.89</td><td>200005</td></tr><tr><td>913</td><td>Maltese Falcon, The (1941)</td><td>3.88</td><td>200006</td></tr></tbody></table></div>

-- %%
 REFRESH MATERIALIZED VIEW movie_catalog.movie_schema.top_movies_per_months_mview
-- Out:
-- ---------------------------------------------------------------------------
-- AnalysisException                         Traceback (most recent call last)
-- File <command-7378309361264946>, line 1
-- ----> 1 get_ipython().run_cell_magic('sql', '', ' REFRESH MATERIALIZED VIEW movie_catalog.movie_schema.top_movies_per_months_mview\n')
--
-- File /databricks/python/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
--    2539 with self.builtin_trap:
--    2540     args = (magic_arg_s, cell)
-- -> 2541     result = fn(*args, **kwargs)
--    2543 # The code below prevents the output from being displayed
--    2544 # when using magics with decorator @output_can_be_silenced
--    2545 # when the last Python token in the expression is a ';'.
--    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:147, in SqlMagic.sql(self, line, cell)
--     143     raise Exception(
--     144         "Cannot run %sql command because spark connect initialization failed and no stacktrace was available."
--     145     )
--     146 if self.use_py4j:
-- --> 147     return self.execute_via_py4j(cell)
--     149 return self.execute_via_sql_comm_handler(cell)
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:231, in SqlMagic.execute_via_py4j(self, cell)
--     228 except BaseException as e:
--     229     self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_FAILED",
--     230                                                        json.dumps(get_debug_info(e)))
-- --> 231     raise e
--     232 self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_SUCCEEDED")
--     233 return result
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:227, in SqlMagic.execute_via_py4j(self, cell)
--     225         print(f"Executing subquery: {query_text}.", file=sys.__stdout__)  # type: ignore
--     226         sql_directive = self.entry_point.getSqlDirective(query_text)
-- --> 227         result = self.handle_sql_directive(sql_directive, i == number_of_sub_queries - 1)
--     228 except BaseException as e:
--     229     self.driver_activity_logger.logExecuteCommandEvent("SQL_MAGIC_PY4J_FAILED",
--     230                                                        json.dumps(get_debug_info(e)))
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:249, in SqlMagic.handle_sql_directive(self, sql_directive, is_last_query)
--     247     df = self.get_query_request_result(f"SELECT * FROM {table_name}")
--     248 elif directive_name == "NoDirective":
-- --> 249     df = self.get_query_request_result(sql_directive.sql())
--     250     if df is None or len(df.schema) == 0:
--     251         # E.g. "create or replace temp view abc as select 1" gets us here and we should not return a result in this case.
--     252         return None
--
-- File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:124, in SqlMagic.get_query_request_result(self, query)
--     122 if len(widget_bindings := self.dbutils.widgets.getAll()) > 0:
--     123     self.driver_activity_logger.logExecuteCommandEvent("PARAM_SYNTAX_USAGE")
-- --> 124 df = self.asserting_spark.sql(query, widget_bindings)
--     125 return df
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/session.py:736, in SparkSession.sql(self, sqlQuery, args, **kwargs)
--     733         _views.append(SubqueryAlias(df._plan, name))
--     735 cmd = SQL(sqlQuery, _args, _named_args, _views)
-- --> 736 data, properties, ei = self.client.execute_command(cmd.command(self._client))
--     737 if "sql_command_result" in properties:
--     738     df = DataFrame(CachedRelation(properties["sql_command_result"]), self)
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1297, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
--    1295     req.user_context.user_id = self._user_id
--    1296 req.plan.command.CopyFrom(command)
-- -> 1297 data, _, metrics, observed_metrics, properties = self._execute_and_fetch(
--    1298     req, observations or {}, extra_request_metadata
--    1299 )
--    1300 # Create a query execution object.
--    1301 ei = ExecutionInfo(metrics, observed_metrics)
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1755, in SparkConnectClient._execute_and_fetch(self, req, observations, extra_request_metadata, self_destruct)
--    1752 properties: Dict[str, Any] = {}
--    1754 with Progress(handlers=self._progress_handlers, operation_id=req.operation_id) as progress:
-- -> 1755     for response in self._execute_and_fetch_as_iterator(
--    1756         req, observations, extra_request_metadata or [], progress=progress
--    1757     ):
--    1758         if isinstance(response, StructType):
--    1759             schema = response
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:1731, in SparkConnectClient._execute_and_fetch_as_iterator(self, req, observations, extra_request_metadata, progress)
--    1729     raise kb
--    1730 except Exception as error:
-- -> 1731     self._handle_error(error)
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:2047, in SparkConnectClient._handle_error(self, error)
--    2045 self.thread_local.inside_error_handling = True
--    2046 if isinstance(error, grpc.RpcError):
-- -> 2047     self._handle_rpc_error(error)
--    2048 elif isinstance(error, ValueError):
--    2049     if "Cannot invoke RPC" in str(error) and "closed" in str(error):
--
-- File /databricks/python/lib/python3.11/site-packages/pyspark/sql/connect/client/core.py:2149, in SparkConnectClient._handle_rpc_error(self, rpc_error)
--    2134                 raise Exception(
--    2135                     "Python versions in the Spark Connect client and server are different. "
--    2136                     "To execute user-defined functions, client and server should have the "
--    (...)
--    2145                     "https://docs.databricks.com/en/release-notes/serverless.html."
--    2146                 )
--    2147             # END-EDGE
-- -> 2149             raise convert_exception(
--    2150                 info,
--    2151                 status.message,
--    2152                 self._fetch_enriched_error(info),
--    2153                 self._display_server_stack_trace(),
--    2154             ) from None
--    2156     raise SparkConnectGrpcException(status.message) from None
--    2157 else:
--
-- AnalysisException: [MATERIALIZED_VIEW_OPERATION_NOT_ALLOWED.REQUIRES_DBSQL_PRO_PLUS] The materialized view operation REFRESH is not allowed: Cannot REFRESH the Materialized View `movie_catalog`.`movie_schema`.`top_movies_per_months_mview` from general compute, please use DBSQL Serverless (recommended) or Pro warehouse. SQLSTATE: 56038
--
-- JVM stacktrace:
-- org.apache.spark.sql.AnalysisException
-- 	at org.apache.spark.sql.errors.QueryCompilationErrors$.materializedViewWriteOperationNotSupportedError(QueryCompilationErrors.scala:1493)
-- 	at com.databricks.sql.util.materializedviews.MaterializedViewMaintenance.writeOperationUnsupportedError(MaterializedViewMaintenance.scala:699)
-- 	at com.databricks.sql.util.materializedviews.MaterializedViewMaintenance.validateCreateOrRefresh(MaterializedViewMaintenance.scala:719)
-- 	at com.databricks.sql.util.materializedviews.MaterializedViewMaintenance.createOrRefreshMaterializedView(MaterializedViewMaintenance.scala:741)
-- 	at com.databricks.sql.util.materializedviews.MaterializedViewMaintenance.createOrRefreshMaterializedView$(MaterializedViewMaintenance.scala:736)
-- 	at org.apache.spark.sql.execution.command.RefreshMaterializedView.createOrRefreshMaterializedView(materializedviews.scala:24)
-- 	at org.apache.spark.sql.execution.command.RefreshMaterializedView.run(materializedviews.scala:50)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.$anonfun$sideEffectResult$2(commands.scala:84)
-- 	at org.apache.spark.sql.execution.SparkPlan.runCommandInAetherOrSpark(SparkPlan.scala:194)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.$anonfun$sideEffectResult$1(commands.scala:84)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:94)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult$lzycompute(commands.scala:81)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult(commands.scala:80)
-- 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.executeCollect(commands.scala:94)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$5(QueryExecution.scala:450)
-- 	at com.databricks.util.LexicalThreadLocal$Handle.runWith(LexicalThreadLocal.scala:63)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$4(QueryExecution.scala:450)
-- 	at org.apache.spark.sql.catalyst.QueryPlanningTracker$.withTracker(QueryPlanningTracker.scala:216)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$3(QueryExecution.scala:449)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$11(SQLExecution.scala:477)
-- 	at com.databricks.sql.util.MemoryTrackerHelper.withMemoryTracking(MemoryTrackerHelper.scala:80)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$10(SQLExecution.scala:413)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:776)
-- 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withNewExecutionId0$1(SQLExecution.scala:343)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1450)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId0(SQLExecution.scala:212)
-- 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:713)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$2(QueryExecution.scala:445)
-- 	at org.apache.spark.sql.execution.QueryExecution$.withInternalError(QueryExecution.scala:1308)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$1(QueryExecution.scala:441)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag(QueryTagger.scala:63)
-- 	at com.databricks.sql.util.ThreadLocalTagger.withTag$(QueryTagger.scala:60)
-- 	at com.databricks.sql.util.QueryTagger$.withTag(QueryTagger.scala:212)
-- 	at org.apache.spark.sql.execution.QueryExecution.withMVTagsIfNecessary(QueryExecution.scala:368)
-- 	at org.apache.spark.sql.execution.QueryExecution.org$apache$spark$sql$execution$QueryExecution$$eagerlyExecute$1(QueryExecution.scala:439)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$8$1.applyOrElse(QueryExecution.scala:503)
-- 	at org.apache.spark.sql.execution.QueryExecution$$anonfun$$nestedInanonfun$eagerlyExecuteCommands$8$1.applyOrElse(QueryExecution.scala:498)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.$anonfun$transformDownWithPruning$1(TreeNode.scala:521)
-- 	at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(origin.scala:85)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDownWithPruning(TreeNode.scala:521)
-- 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.org$apache$spark$sql$catalyst$plans$logical$AnalysisHelper$$super$transformDownWithPruning(LogicalPlan.scala:42)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning(AnalysisHelper.scala:361)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper.transformDownWithPruning$(AnalysisHelper.scala:357)
-- 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:42)
-- 	at org.apache.spark.sql.catalyst.plans.logical.LogicalPlan.transformDownWithPruning(LogicalPlan.scala:42)
-- 	at org.apache.spark.sql.catalyst.trees.TreeNode.transformDown(TreeNode.scala:497)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$eagerlyExecuteCommands$8(QueryExecution.scala:498)
-- 	at org.apache.spark.sql.catalyst.plans.logical.AnalysisHelper$.allowInvokingTransformsInAnalyzer(AnalysisHelper.scala:418)
-- 	at org.apache.spark.sql.execution.QueryExecution.eagerlyExecuteCommands(QueryExecution.scala:498)
-- 	at org.apache.spark.sql.execution.QueryExecution.$anonfun$lazyCommandExecuted$1(QueryExecution.scala:326)
-- 	at scala.util.Try$.apply(Try.scala:213)
-- 	at org.apache.spark.util.Utils$.doTryWithCallerStacktrace(Utils.scala:1684)
-- 	at org.apache.spark.util.Utils$.getTryWithCallerStacktrace(Utils.scala:1745)
-- 	at org.apache.spark.util.LazyTry.get(LazyTry.scala:58)
-- 	at org.apache.spark.sql.execution.QueryExecution.commandExecuted(QueryExecution.scala:331)
-- 	at org.apache.spark.sql.Dataset.<init>(Dataset.scala:406)
-- 	at org.apache.spark.sql.Dataset$.$anonfun$ofRows$3(Dataset.scala:150)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1450)
-- 	at org.apache.spark.sql.SparkSession.$anonfun$withActiveAndFrameProfiler$1(SparkSession.scala:1457)
-- 	at com.databricks.spark.util.FrameProfiler$.record(FrameProfiler.scala:94)
-- 	at org.apache.spark.sql.SparkSession.withActiveAndFrameProfiler(SparkSession.scala:1457)
-- 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:141)
-- 	at org.apache.spark.sql.SparkSession.$anonfun$sql$4(SparkSession.scala:1130)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1450)
-- 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:1082)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.executeSQL(SparkConnectPlanner.scala:3606)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.handleSqlCommand(SparkConnectPlanner.scala:3435)
-- 	at org.apache.spark.sql.connect.planner.SparkConnectPlanner.process(SparkConnectPlanner.scala:3370)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.handleCommand(ExecuteThreadRunner.scala:413)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1(ExecuteThreadRunner.scala:312)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.$anonfun$executeInternal$1$adapted(ExecuteThreadRunner.scala:233)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$2(SessionHolder.scala:464)
-- 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:1450)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.$anonfun$withSession$1(SessionHolder.scala:464)
-- 	at org.apache.spark.JobArtifactSet$.withActiveJobArtifactState(JobArtifactSet.scala:97)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.$anonfun$withResources$1(ArtifactManager.scala:90)
-- 	at org.apache.spark.util.Utils$.withContextClassLoader(Utils.scala:241)
-- 	at org.apache.spark.sql.artifact.ArtifactManager.withResources(ArtifactManager.scala:89)
-- 	at org.apache.spark.sql.connect.service.SessionHolder.withSession(SessionHolder.scala:463)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.executeInternal(ExecuteThreadRunner.scala:233)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner.org$apache$spark$sql$connect$execution$ExecuteThreadRunner$$execute(ExecuteThreadRunner.scala:139)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.$anonfun$run$2(ExecuteThreadRunner.scala:614)
-- 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
-- 	at com.databricks.unity.UCSEphemeralState$Handle.runWith(UCSEphemeralState.scala:51)
-- 	at com.databricks.unity.HandleImpl.runWith(UCSHandle.scala:104)
-- 	at com.databricks.unity.HandleImpl.$anonfun$runWithAndClose$1(UCSHandle.scala:109)
-- 	at scala.util.Using$.resource(Using.scala:269)
-- 	at com.databricks.unity.HandleImpl.runWithAndClose(UCSHandle.scala:108)
-- 	at org.apache.spark.sql.connect.execution.ExecuteThreadRunner$ExecutionThread.run(ExecuteThreadRunner.scala:614)

-- %%
select * from movie_catalog.movie_schema.movie_rating_history_dlt where  `__END_AT` is not null  limit 10
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MovieID</th><th>Rating_status</th><th>__START_AT</th><th>__END_AT</th></tr></thead><tbody><tr><td>170</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr><tr><td>208</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr><tr><td>253</td><td>GOOD</td><td>200004</td><td>200005</td></tr><tr><td>303</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr><tr><td>317</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr><tr><td>344</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr><tr><td>367</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr><tr><td>372</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr><tr><td>434</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr><tr><td>454</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr></tbody></table></div>

-- %%
select * from  movie_catalog.movie_schema.movie_rating_history_dlt where MovieID = 170;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MovieID</th><th>Rating_status</th><th>__START_AT</th><th>__END_AT</th></tr></thead><tbody><tr><td>170</td><td>AVERAGE</td><td>200004</td><td>200005</td></tr><tr><td>170</td><td>GOOD</td><td>200005</td><td>null</td></tr></tbody></table></div>

-- %%
select count(distinct Review_ym),MovieID from movie_catalog.movie_schema.movie_ratings_silver_st
where Rating in(2,3,4)
group by MovieID having count(distinct Review_ym) >1  limit 10
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(DISTINCTReview_ym)</th><th>MovieID</th></tr></thead><tbody></tbody></table></div>

-- %%
select *  from movie_catalog.movie_schema.movie_ratings_silver_st where MovieID = 2936
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MovieID</th><th>Rating</th><th>Review_ym</th><th>_rescued_data</th></tr></thead><tbody><tr><td>2936</td><td>3</td><td>200004</td><td>null</td></tr><tr><td>2936</td><td>3</td><td>200004</td><td>null</td></tr></tbody></table></div>

-- %%
select distinct Review_ym from movie_catalog.movie_schema.movie_ratings_silver_st
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Review_ym</th></tr></thead><tbody><tr><td>200005</td></tr><tr><td>200006</td></tr><tr><td>200004</td></tr></tbody></table></div>

-- %%
select * from movie_catalog.movie_schema.Movie_ratings_gold_st order by MovieID limit 100
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MovieID</th><th>Rating_count</th><th>Rating_avg</th><th>Rating_status</th><th>Review_ym</th></tr></thead><tbody><tr><td>1</td><td>12</td><td>3.5</td><td>GOOD</td><td>200004</td></tr><tr><td>1</td><td>97</td><td>3.62</td><td>GOOD</td><td>200005</td></tr><tr><td>2</td><td>40</td><td>3.25</td><td>GOOD</td><td>200005</td></tr><tr><td>2</td><td>9</td><td>3.22</td><td>GOOD</td><td>200004</td></tr><tr><td>3</td><td>15</td><td>3.07</td><td>GOOD</td><td>200005</td></tr><tr><td>4</td><td>15</td><td>3.0</td><td>AVERAGE</td><td>200005</td></tr><tr><td>4</td><td>6</td><td>2.67</td><td>AVERAGE</td><td>200004</td></tr><tr><td>5</td><td>21</td><td>3.29</td><td>GOOD</td><td>200005</td></tr><tr><td>6</td><td>7</td><td>3.71</td><td>GOOD</td><td>200004</td></tr><tr><td>6</td><td>39</td><td>3.41</td><td>GOOD</td><td>200005</td></tr><tr><td>7</td><td>36</td><td>3.36</td><td>GOOD</td><td>200005</td></tr><tr><td>7</td><td>6</td><td>3.33</td><td>GOOD</td><td>200004</td></tr><tr><td>10</td><td>11</td><td>3.64</td><td>GOOD</td><td>200004</td></tr><tr><td>10</td><td>57</td><td>3.25</td><td>GOOD</td><td>200005</td></tr><tr><td>11</td><td>11</td><td>3.36</td><td>GOOD</td><td>200004</td></tr><tr><td>11</td><td>62</td><td>3.56</td><td>GOOD</td><td>200005</td></tr><tr><td>12</td><td>6</td><td>2.5</td><td>AVERAGE</td><td>200005</td></tr><tr><td>14</td><td>8</td><td>3.38</td><td>GOOD</td><td>200005</td></tr><tr><td>16</td><td>24</td><td>3.33</td><td>GOOD</td><td>200005</td></tr><tr><td>17</td><td>48</td><td>3.67</td><td>GOOD</td><td>200005</td></tr><tr><td>17</td><td>6</td><td>3.5</td><td>GOOD</td><td>200004</td></tr><tr><td>19</td><td>8</td><td>2.75</td><td>AVERAGE</td><td>200005</td></tr><tr><td>21</td><td>78</td><td>3.47</td><td>GOOD</td><td>200005</td></tr><tr><td>21</td><td>16</td><td>3.25</td><td>GOOD
td>2</td><td>1049</td></tr><tr><td>2</td><td>3489</td></tr><tr><td>2</td><td>1215</td></tr><tr><td>2</td><td>2455</td></tr><tr><td>2</td><td>2058</td></tr><tr><td>2</td><td>1073</td></tr><tr><td>2</td><td>2528</td></tr><tr><td>2</td><td>2746</td></tr><tr><td>2</td><td>3396</td></tr><tr><td>2</td><td>1645</td></tr><tr><td>2</td><td>2529</td></tr><tr><td>2</td><td>2115</td></tr><tr><td>2</td><td>1222</td></tr><tr><td>2</td><td>593</td></tr><tr><td>3</td><td>2628</td></tr><tr><td>2</td><td>1777</td></tr><tr><td>2</td><td>3614</td></tr><tr><td>2</td><td>2581</td></tr><tr><td>2</td><td>708</td></tr><tr><td>2</td><td>1320</td></tr><tr><td>2</td><td>1228</td></tr><tr><td>2</td><td>1377</td></tr><tr><td>2</td><td>1876</td></tr><tr><td>2</td><td>1997</td></tr><tr><td>2</td><td>2161</td></tr><tr><td>2</td><td>1617</td></tr><tr><td>2</td><td>908</td></tr><tr><td>2</td><td>3448</td></tr><tr><td>2</td><td>1959</td></tr><tr><td>2</td><td>968</td></tr><tr><td>2</td><td>2013</td></tr><tr><td>2</td><td>300</td></tr><tr><td>2</td><td>474</td></tr><tr><td>2</td><td>1500</td></tr><tr><td>2</td><td>2005</td></tr><tr><td>2</td><td>3334</td></tr><tr><td>2</td><td>1 ...

-- %%
select * from movie_catalog.movie_schema.Movie_ratings_gold_st where MovieID = 2613
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>MovieID</th><th>Rating_count</th><th>Rating_avg</th><th>Rating_status</th><th>Review_ym</th></tr></thead><tbody><tr><td>2613</td><td>11</td><td>3.36</td><td>GOOD</td><td>200006</td></tr><tr><td>2613</td><td>6</td><td>3.0</td><td>AVERAGE</td><td>200004</td></tr><tr><td>2613</td><td>15</td><td>2.87</td><td>AVERAGE</td><td>200005</td></tr></tbody></table></div>

-- %%
 SELECT timestamp, message, details
  FROM event_log(table(movie_catalog.movie_schema.movie_rating_history_dlt))
  WHERE level in ('INFO', 'WARN', 'ERROR')
  ORDER BY timestamp desc limit 100;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp</th><th>message</th><th>details</th></tr></thead><tbody><tr><td>2025-07-24T09:14:39.399Z</td><td>Update f4fc01 is COMPLETED.</td><td>{"update_progress":{"state":"COMPLETED"}}</td></tr><tr><td>2025-07-24T09:14:38.312Z</td><td>Flow 'movie_catalog.movie_schema.movie_rating_history_dlt' has COMPLETED.</td><td>{"flow_progress":{"status":"COMPLETED"}}</td></tr><tr><td>2025-07-24T09:14:38.280Z</td><td>Completed a streaming update of 'movie_catalog.movie_schema.movie_rating_history_dlt'.</td><td>{"flow_progress":{"status":"RUNNING","metrics":{"backlog_bytes":0,"backlog_files":0,"num_upserted_rows":2193,"num_deleted_rows":0,"source_metrics":[{"source_name":"DeltaSource[movie_catalog.movie_schema.movie_ratings_gold_st]","backlog_bytes":0,"backlog_files":0}]},"data_quality":{"dropped_records":0},"streaming_metrics":{"event_time":{}}}}</td></tr><tr><td>2025-07-24T09:14:26.339Z</td><td>Flow 'movie_catalog.movie_schema.movie_rating_history_dlt' is RUNNING.</td><td>{"flow_progress":{"status":"RUNNING","metrics":{}}}</td></tr><tr><td>2025-07-24T09:14:26.061Z</td><td>Flow 'movie_catalog.movie_schema.movie_rating_history_dlt' is STARTING.</td><td>{"flow_progress":{"status":"STARTING"}}</td></tr><tr><td>2025-07-24T09:14:23.983Z</td><td>Flow 'movie_catalog.movie_schema.movie_ratings_gold_ingest_flow' has COMPLETED.</td><td>{"flow_progress":{"status":"COMPLETED"}}</td></tr><tr><td>2025-07-24T09:14:23.950Z</td><td>Completed a streaming update of 'movie_catalog.movie_schema.movie_ratings_gold_ingest_flow'.</td><td>{"flow_progress":{"status":"RUNNING","metrics":{"num_output_rows":3882,"backlog_bytes":0,"backlog_files":0,"source_metrics":[{"source_name":"DeltaSource[movie_catalog.movie_schema.movie_ratings_silver_st]","backlog_bytes":0,"backlog_files":0}]},"data_quality":{"dropped_records":0},"streaming_metrics":{"event_time":{}}}}</td></tr><tr><td>2025-07-24T09:14:14.100Z</td><td>Flow 'movie_catalog.movie_schema.top_movies_per_months_mview' has COMPLETED.</td><td>{"flow_progress":{"status":"COMPLETED","metrics":{},"data_quality":{}}}</td></tr><tr><td>2025-07-24T09:14:07.175Z</td><td>Flow 'movie_catalog.movie_schema.top_movies_per_months_mview' is RUNNING.</td><td>{"flow_progress":{"status":"RUNNING","metrics":{"backlog_bytes":595266,"backlog_files":14}}}</td></tr><tr><td>2025-07-24T09:14:07.025Z</td><td>Flow 'movie_catalog.movie_schema.top_movies_per_months_mview' is STARTING.</td><td>{"flow_progress":{"status":"STARTING"}}</td></tr><tr><td>2025-07-24T09:14:06.945Z</td><td>Flow 'movie_catalog.movie_schema.top_movies_per_months_mview' has been planned in DLT to be executed as COMPLETE_RECOMPUTE.</td><td>{"planning_information":{"technique_information":[{"maintenance_type":"MAINTENANCE_TYPE_NO_OP","incrementalization_issues":[{"issue_type":"DATA_HAS_CHANGED","prevent_incrementalization":true}]},{"maintenance_type":"MAINTENANCE_TYPE_ROW_BASED","incrementalization_issues":[{"issue_type":"PLAN_NOT_INCREMENTALIZABLE","prevent_incrementalization":true,"operator_name":"Sort","plan_not_incrementalizable_sub_type":"OPERATOR_NOT_SUPPORTED"}]},{"maintenance_type":"MAINTENANCE_TYPE_COMPLETE_RECOMPUTE","is_chosen":true,"is_applicable":true,"cost":3.422528061629811E15}],"source_table_information":[{"table_id":"b7232f83-89cf-498b-a43e-93c083372d8f","full_size":197706.0,"num_rows":93743,"num_files":3,"is_size_after_pruning":true,"is_row_id_enabled":true,"is_cdf_enabled":true,"is_deletion_vector_enabled":true},{"table_name":"`movie_catalog`.`movie_schema`.`movie_dim`","table_id":"f60d3514-93f4-43e7-8aca-fa27c64db509","catalog_table_type":"MANAGED","full_size":99927.0,"num_rows":3883,"num_files":4,"is_size_after_pruning":true,"is_row_id_enabled":false,"is_cdf_enabled":false,"is_deletion_vector_enabled":true}],"target_table_information":{"table_name":"`movie_catalog`.`movie_schema`.`top_movies_per_months_mview`","table_id":"cf29eec8-902d-4f72- ...

-- %%
 SELECT *
  FROM event_log(table(movie_catalog.movie_schema.movie_rating_history_dlt))
  WHERE level in ('INFO', 'WARN', 'ERROR')
  ORDER BY timestamp desc limit 100;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>sequence</th><th>origin</th><th>timestamp</th><th>message</th><th>level</th><th>maturity_level</th><th>error</th><th>details</th><th>event_type</th></tr></thead><tbody><tr><td>a0534b70-686e-11f0-80b2-dedd54b531f1</td><td>List(List(execution, 1753348391784061), null)</td><td>List(AWS, us-east-2, 55054304872059, null, f055aaf2-89e1-4868-8aa3-c0c7759863cd, WORKSPACE, Streaming_pipeline_with_movie_ratings, 0724-091246-fvwj9sbg-v2n, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, null, null, null, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, null, null, null, null, null, null, null, null, null)</td><td>2025-07-24T09:14:39.399Z</td><td>Update f4fc01 is COMPLETED.</td><td>INFO</td><td>STABLE</td><td>null</td><td>{"update_progress":{"state":"COMPLETED"}}</td><td>update_progress</td></tr><tr><td>9fad6e80-686e-11f0-80b2-dedd54b531f1</td><td>List(List(execution, 1753348391784057), null)</td><td>List(AWS, us-east-2, 55054304872059, null, f055aaf2-89e1-4868-8aa3-c0c7759863cd, WORKSPACE, Streaming_pipeline_with_movie_ratings, 0724-091246-fvwj9sbg-v2n, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, 46f0799b-9123-46b1-92ec-4a9194656c8b, movie_catalog.movie_schema.movie_rating_history_dlt, null, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, null, null, null, null, null, null, null, null, null)</td><td>2025-07-24T09:14:38.312Z</td><td>Flow 'movie_catalog.movie_schema.movie_rating_history_dlt' has COMPLETED.</td><td>INFO</td><td>STABLE</td><td>null</td><td>{"flow_progress":{"status":"COMPLETED"}}</td><td>flow_progress</td></tr><tr><td>9fa88c80-686e-11f0-80b2-dedd54b531f1</td><td>List(List(execution, 1753348391784056), null)</td><td>List(AWS, us-east-2, 55054304872059, null, f055aaf2-89e1-4868-8aa3-c0c7759863cd, WORKSPACE, Streaming_pipeline_with_movie_ratings, 0724-091246-fvwj9sbg-v2n, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, 46f0799b-9123-46b1-92ec-4a9194656c8b, movie_catalog.movie_schema.movie_rating_history_dlt, null, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, null, null, null, null, null, null, null, null, null)</td><td>2025-07-24T09:14:38.280Z</td><td>Completed a streaming update of 'movie_catalog.movie_schema.movie_rating_history_dlt'.</td><td>INFO</td><td>STABLE</td><td>null</td><td>{"flow_progress":{"status":"RUNNING","metrics":{"backlog_bytes":0,"backlog_files":0,"num_upserted_rows":2193,"num_deleted_rows":0,"source_metrics":[{"source_name":"DeltaSource[movie_catalog.movie_schema.movie_ratings_gold_st]","backlog_bytes":0,"backlog_files":0}]},"data_quality":{"dropped_records":0},"streaming_metrics":{"event_time":{}}}}</td><td>flow_progress</td></tr><tr><td>988a7f30-686e-11f0-80b2-dedd54b531f1</td><td>List(List(execution, 1753348391784055), null)</td><td>List(AWS, us-east-2, 55054304872059, null, f055aaf2-89e1-4868-8aa3-c0c7759863cd, WORKSPACE, Streaming_pipeline_with_movie_ratings, 0724-091246-fvwj9sbg-v2n, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, 46f0799b-9123-46b1-92ec-4a9194656c8b, movie_catalog.movie_schema.movie_rating_history_dlt, null, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, null, null, null, null, null, null, null, null, null)</td><td>2025-07-24T09:14:26.339Z</td><td>Flow 'movie_catalog.movie_schema.movie_rating_history_dlt' is RUNNING.</td><td>INFO</td><td>STABLE</td><td>null</td><td>{"flow_progress":{"status":"RUNNING","metrics":{}}}</td><td>flow_progress</td></tr><tr><td>986013d0-686e-11f0-80b2-dedd54b531f1</td><td>List(List(execution, 1753348391784054), null)</td><td>List(AWS, us-east-2, 55054304872059, null, f055aaf2-89e1-4868-8aa3-c0c7759863cd, WORKSPACE, Streaming_pipeline_with_movie_ratings, 0724-091246-fvwj9sbg-v2n, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, null, movie_catalog.movie_schema.movie_rating_history_dlt, null, f4fc0198-ae92-41a3-8245-6501733ce0ca, null, null, null, null, nu ...
