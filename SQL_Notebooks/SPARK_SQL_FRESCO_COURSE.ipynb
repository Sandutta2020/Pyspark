# %%
spark

# %%
spark.sql("DROP TABLE IF EXISTS SAMPLE_TABLE")
# Out:
# DataFrame[]

# %%
df=spark.read.csv("/databricks-datasets/flights/departuredelays.csv",header=True)

# %%
df.createOrReplaceTempView("departure_delays")

# %%
sqldf=spark.sql("select * from departure_delays")
sqldf.show()
# Out:
# +--------+-----+--------+------+-----------+
# |    date|delay|distance|origin|destination|
# +--------+-----+--------+------+-----------+
# |01011245|    6|     602|   ABE|        ATL|
# |01020600|   -8|     369|   ABE|        DTW|
# |01021245|   -2|     602|   ABE|        ATL|
# |01020605|   -4|     602|   ABE|        ATL|
# |01031245|   -4|     602|   ABE|        ATL|
# |01030605|    0|     602|   ABE|        ATL|
# |01041243|   10|     602|   ABE|        ATL|
# |01040605|   28|     602|   ABE|        ATL|
# |01051245|   88|     602|   ABE|        ATL|
# |01050605|    9|     602|   ABE|        ATL|
# |01061215|   -6|     602|   ABE|        ATL|
# |01061725|   69|     602|   ABE|        ATL|
# |01061230|    0|     369|   ABE|        DTW|
# |01060625|   -3|     602|   ABE|        ATL|
# |01070600|    0|     369|   ABE|        DTW|
# |01071725|    0|     602|   ABE|        ATL|
# |01071230|    0|     369|   ABE|        DTW|
# |01070625|    0|     602|   ABE|        ATL|
# ...

# %%
df.createGlobalTempView("Global_view")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6582217898857738>, line 1
# ----> 1 df.createGlobalTempView("Global_view")
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/dataframe.py:2082, in DataFrame.createGlobalTempView(self, name)
#    2078 def createGlobalTempView(self, name: str) -> None:
#    2079     command = plan.CreateView(
#    2080         child=self._plan, name=name, is_global=True, replace=False
#    2081     ).command(session=self._session.client)
# -> 2082     _, _, ei = self._session.client.execute_command(command, self._plan.observations)
#    2083     self._execution_info = ei
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1556, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
# ...
