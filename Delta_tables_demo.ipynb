-- %%
%python
database_name = "my_database"

# Create the database if it does not exist
spark.sql(f"CREATE DATABASE IF NOT EXISTS {database_name}")

# Define the table name
table_name = "taxis_delta"

-- %%
%fs ls /databricks-datasets/delta-sharing/samples/nyctaxi_2019/
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
%fs head /databricks-datasets/delta-sharing/samples/README.md
-- Out:
-- # Delta Sharing Sample datasets
--
-- The following are datasets in Delta format with attributions to their original formats noted.
--
-- * boston-housing: Original source: https://www.kaggle.com/c/boston-housing
-- * COVID-19_NYT: Original source: https://github.com/nytimes/covid-19-data
-- * flight-asa_2008: Original source: http://stat-computing.org/dataexpo/2009/
-- * lending_club: Origial source: https://www.kaggle.com/wendykan/lending-club-loan-data
-- * nyctaxi_2019: https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page
-- * owid-covid-data: https://covid.ourworldindata.org/data/owid-covid-data.csv

-- %% [markdown]
-- Analysing the code first

-- %%
%sql
select * from delta.`/databricks-datasets/delta-sharing/samples/nyctaxi_2019` limit 100
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
